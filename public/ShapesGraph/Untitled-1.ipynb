# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # Step 1: Read CSV
# df = pd.read_csv('//home//rmt//RMT//TelestrokeFront//public//ShapesGraph//HorizX.csv')

# # Step 2: Check column names
# print(df.columns)

# # Step 3: Plot using correct column names
# plt.figure(figsize=(10,6))
# plt.plot(df['Time (s)'], df['X Position (pixels)'], marker='o', linestyle='-', color='blue')
# plt.xlabel('Time (s)')
# plt.ylabel('X Position (pixels)')
# plt.title('Eye Tracking Data')
# plt.grid(True)
# plt.show()



#HORIZONTAL 
import pandas as pd
import matplotlib.pyplot as plt

# Read CSV
df = pd.read_csv('//home//rmt//RMT//TelestrokeFront//public//ShapesGraph//HorizY.csv')

# Check column names
print(df.columns)  # ['Time (s)', 'Y Position (pixels)']

# Plot
plt.figure(figsize=(10,6))
plt.plot(df['Time (s)'], df['Y Position (pixels)'], marker='o', linestyle='-', color='blue')
plt.xlabel('Time (s)')
plt.ylabel('Y Position (pixels)')
plt.title('Eye Tracking Data')
plt.grid(True)
plt.show()
# Out:
# Index(['Time (s)', 'Y Position (pixels)'], dtype='object')
